# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数
loss_fn = torch.nn.MSELoss()

# 定义优化器和超参数
optimizer = torch.optim.SGD([w, b], lr=0.1)
epochs = 100

# 批量梯度下降
for epoch in range(epochs):
    # 前向传播
    Y_pred = w * X + b
    # 计算损失
    loss = loss_fn(Y_pred, Y)
    # 清空梯度
    optimizer.zero_grad()
    # 反向传播
    loss.backward()
    # 更新参数
    optimizer.step()

# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.title("Batch Gradient Descent")
plt.scatter(X.numpy(), Y.numpy())
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/Batch Gradient Descent.svg")
plt.show()
# Out:
# w = 1.9900766611099243, b = 0.02917606569826603, loss = 0.0001510764705017209

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.SGD([w, b], lr=0.1)

# 定义超参数
batch_size = 2
epochs = 100

# 随机梯度下降
for epoch in range(epochs):
    # 创建DataLoader
    loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X, Y), batch_size=batch_size, shuffle=True)
    for x_batch, y_batch in loader:
        # 前向传播
        y_pred = w * x_batch + b
        # 计算损失
        loss = loss_fn(y_pred, y_batch)
        # 反向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 清空梯度
        optimizer.zero_grad()


# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("Stochastic Gradient Descent")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/Stochastic Gradient Descent.svg")
plt.show()
# Out:
# w = 1.9999330043792725, b = 0.00044925438123755157, loss = 1.0989697329932824e-07

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.SGD([w, b], lr=0.1)

# 定义超参数
batch_size = 1
epochs = 100

# 小批量梯度下降
for epoch in range(epochs):
    # 创建DataLoader
    loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X, Y), batch_size=batch_size, shuffle=True)
    for x_batch, y_batch in loader:
        # 前向传播
        y_pred = w * x_batch + b
        # 计算损失
        loss = loss_fn(y_pred, y_batch)
        # 反向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 清空梯度
        optimizer.zero_grad()

# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("Mini-batch Gradient Descent")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/Mini-batch Gradient Descent.svg")
plt.show()
# Out:
# w = 1.9999994039535522, b = 7.853239480937191e-07, loss = 9.094947017729282e-13

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数和动量
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)
momentum = 0.9

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.SGD([w, b], lr=0.1, momentum=momentum)



# 定义超参数
epochs = 100

# 动量梯度下降
for epoch in range(epochs):
    # 前向传播
    y_pred = w * X + b
    # 计算损失
    loss = loss_fn(y_pred, Y)
    # 反向传播
    loss.backward()
    # 更新参数
    optimizer.step()
    # 清空梯度
    optimizer.zero_grad()

# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("Momentum Gradient Descent")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/Momentum Gradient Descent.svg")
plt.show()
# Out:
# w = 1.9952116012573242, b = -0.00337416073307395, loss = 0.0013349037617444992

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adagrad([w, b], lr=0.1)

# 定义超参数
epochs = 100

# AdaGrad
for epoch in range(epochs):
    # 前向传播
    y_pred = w * X + b
    # 计算损失
    loss = loss_fn(y_pred, Y)
    # 反向传播
    loss.backward()
    # 更新参数
    optimizer.step()
    # 清空梯度
    optimizer.zero_grad()

# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("AdaGrad")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/AdaGrad.svg")
plt.show()
# Out:
# w = 1.2874746322631836, b = 1.2326067686080933, loss = 0.9546705484390259

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.RMSprop([w, b], lr=0.1)

# 定义超参数
epochs = 100

# RMSprop
for epoch in range(epochs):
    # 前向传播
    y_pred = w * X + b
    # 计算损失
    loss = loss_fn(y_pred, Y)
    # 反向传播
    loss.backward()
    # 更新参数
    optimizer.step()
    # 清空梯度
    optimizer.zero_grad()

# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("RMSprop")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/RMSprop.svg")
plt.show()
# Out:
# w = 1.9748035669326782, b = 0.07184594124555588, loss = 0.0009426436154171824

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam([w, b], lr=0.1)

# 定义超参数
epochs = 100

# Adam
for epoch in range(epochs):
    # 前向传播
    y_pred = w * X + b
    # 计算损失
    loss = loss_fn(y_pred, Y)
    # 反向传播
    loss.backward()
    # 更新参数
    optimizer.step()
    # 清空梯度
    optimizer.zero_grad()
loss = loss_fn(y_pred, Y)
# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("Adam")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/Adam.svg")
plt.show()
# Out:
# w = 1.7332017421722412, b = 0.7382447719573975, loss = 0.09637077152729034

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.AdamW([w, b], lr=0.1, weight_decay=0.1)

# 定义超参数
epochs = 100

# AdamW
for epoch in range(epochs):
    # 前向传播
    y_pred = w * X + b
    # 计算损失
    loss = loss_fn(y_pred, Y)
    # 反向传播
    loss.backward()
    # 更新参数
    optimizer.step()
    # 清空梯度
    optimizer.zero_grad()

loss = loss_fn(y_pred, Y)
# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("AdamW")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/AdamW.svg")
plt.show()
# Out:
# w = 1.6086859703063965, b = 0.9154295325279236, loss = 0.19812753796577454

# %%
import torch
import matplotlib.pyplot as plt

# 定义训练数据
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

# 初始化模型参数
w = torch.tensor(0.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# 定义损失函数和优化器
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adadelta([w, b], lr=0.1)

# 定义超参数
epochs = 100

# Adadelta
for epoch in range(epochs):
    # 前向传播
    y_pred = w * X + b
    # 计算损失
    loss = loss_fn(y_pred, Y)
    # 反向传播
    loss.backward()
    # 更新参数
    optimizer.step()
    # 清空梯度
    optimizer.zero_grad()

loss = loss_fn(y_pred, Y)
# 输出结果
print(f"w = {w.item()}, b = {b.item()}, loss = {loss.item()}")

# 绘制拟合直线
plt.scatter(X.numpy(), Y.numpy())
plt.title("Adadelta")
plt.plot(X.numpy(), (w * X + b).detach().numpy(), 'r')
plt.savefig("./png/Adadelta.svg")
plt.show()
# Out:
# w = 0.04020601138472557, b = 0.040185488760471344, loss = 28.431560516357422
